# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import interpolate, optimize
import ddm
import os 
import csv

# %%
class LossWLS(ddm.LossFunction):
    name = 'Weighted least squares as described in Ratcliff & Tuerlinckx 2002'
    rt_quantiles = [0.1, 0.3, 0.5, 0.7, 0.9]
    rt_q_weights = [2, 2, 1, 1, 0.5]
#     exp_data = pd.read_csv('../data/measures.csv', 
#                             usecols=['subj_id', 'RT', 'is_turn_decision', 'tta_condition', 'd_condition'])
           
    def setup(self, dt, T_dur, **kwargs):
        self.dt = dt
        self.T_dur = T_dur
    
    def get_rt_quantiles(self, x, t_domain, exp=False):
        cdf = x.cdf_corr(T_dur=self.T_dur, dt=self.dt) if exp else x.cdf_corr()
        cdf_interp = interpolate.interp1d(t_domain, cdf/cdf[-1])
        # If the model produces very fast RTs, interpolated cdf(0) can be >0.1, then we cannot find root like usual
        # In this case, the corresponding rt quantile is half of the time step of cdf
        rt_quantile_values = [optimize.root_scalar(lambda x:cdf_interp(x)-quantile, bracket=(0, t_domain[-1])).root
                              if (cdf_interp(0)<quantile) else self.dt/2
                              for quantile in self.rt_quantiles]
        return np.array(rt_quantile_values)
    
    def loss(self, model):
        solultions = self.cache_by_conditions(model)
        WLS = 0
        for comb in self.sample.condition_combinations(required_conditions=self.required_conditions):
            c = frozenset(comb.items())
            comb_sample = self.sample.subset(**comb)
            WLS += 4*(solultions[c].prob_correct() - comb_sample.prob_correct())**2            
            # Sometimes model p_correct is very close to 0, then RT distribution is weird, in this case ignore RT error 
            if ((solultions[c].prob_correct()>0.001) & (comb_sample.prob_correct()>0)):
#                 self.condition_data = self.exp_data[(self.exp_data.d_condition==comb['d_condition']) 
#                                                     & (self.exp_data.tta_condition==comb['tta_condition'])]
#                 self.condition_data = list(comb_sample.items(correct=True))
                model_rt_q = self.get_rt_quantiles(solultions[c], model.t_domain(), exp=False)
                exp_rt_q = self.get_rt_quantiles(comb_sample, model.t_domain(), exp=True)
                WLS += np.dot((model_rt_q-exp_rt_q)**2, self.rt_q_weights)*comb_sample.prob_correct()
        return WLS

# %%
T_dur = 2.5

class DriftTtaDistance(ddm.models.Drift):
    name = 'Drift depends on TTA and distance'
    required_parameters = ['alpha', 'tta_crit', 'beta', 'd_crit']
    required_conditions = ['tta_condition', 'd_condition'] 
    
    def get_drift(self, t, conditions, **kwargs):
        v = conditions['d_condition']/conditions['tta_condition']
        return (self.alpha*(conditions['tta_condition'] - t - self.tta_crit + 
                            self.beta*(conditions['d_condition'] - v*t - self.d_crit)))

class BoundCollapsingTta(ddm.models.Bound):
    name = 'Bounds collapsing with TTA'
    required_parameters = ['b_0', 'k', 'tta_crit']
    required_conditions = ['tta_condition'] 
    def get_bound(self, t, conditions, **kwargs):
        tau = conditions['tta_condition'] - t
        return self.b_0/(1+np.exp(-self.k*(tau-self.tta_crit)))

param_names = ['alpha', 'tta_crit', 'beta', 'd_crit', 'noise', 'b_0', 'k', 'tta_crit', 'nondectime', 'halfwidth']
tta_crit = ddm.Fittable(minval=3, maxval=6)
model_TTA_bounds = ddm.Model(name='5 TTA- and d-dependent drift and bounds and uniformly distributed nondecision time',
                             drift=DriftTtaDistance(alpha=ddm.Fittable(minval=0.1, maxval=3),
                                                     tta_crit=tta_crit,
                                                     beta=ddm.Fittable(minval=0, maxval=1),
                                                     d_crit=ddm.Fittable(minval=90, maxval=150)),
                             noise=ddm.NoiseConstant(noise=1),
                             bound=BoundCollapsingTta(b_0=ddm.Fittable(minval=0.5, maxval=5), 
                                                      k=ddm.Fittable(minval=0.1, maxval=2),
                                                      tta_crit=tta_crit),
                             overlay=ddm.OverlayNonDecisionUniform(nondectime=ddm.Fittable(minval=0, maxval=0.5),
                                                                   halfwidth=ddm.Fittable(minval=0, maxval=0.3)),
                             T_dur=T_dur)

# %%
def fit_model(model, exp_data, subj_id):
    print(subj_id)
    training_data = exp_data[(exp_data.subj_id == subj_id)] 
#                              & ~((exp_data.d_condition==condition['d']) & (exp_data.tta_condition==condition['tta']))]
    training_sample = ddm.Sample.from_pandas_dataframe(df=training_data, 
                                                       rt_column_name='RT', correct_column_name='is_turn_decision')
    return(ddm.fit_adjust_model(sample=training_sample, model=model, lossfunction=LossWLS, suppress_output=True))

def write_to_csv(directory, filename, array):
    if not os.path.exists(directory):
        os.makedirs(directory)
    with open(os.path.join(directory, filename), 'a', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=',')
        writer.writerow(array)

# %%
model = model_TTA_bounds

exp_data = pd.read_csv('../data/measures.csv', usecols=['subj_id', 'RT', 'is_turn_decision', 
                                                        'tta_condition', 'd_condition'])
subjects = exp_data.subj_id.unique()
# conditions = [{'tta': tta, 'd': d} 
#                   for tta in exp_data.tta_condition.unique() 
#                   for d in exp_data.d_condition.unique()]

directory = '../model_fit_results/'
write_to_csv(directory, 'model_%s_params_by_subject.csv' % (model.name[0]), 
             ['subj_id', 'i', 'loss'] + param_names)

for subj_id in subjects:
#     for condition in conditions:
    for i in range(5):
        fitted_model = fit_model(model, exp_data, subj_id)
        write_to_csv(directory, 'model_%s_params_by_subject.csv' % (model.name[0]), 
                     [subj_id, i, fitted_model.get_fit_result().value()] 
                     + fitted_model.get_model_parameters())
# Out:
# 129
# differential_evolution step 1: f(x)= 1.97525
# differential_evolution step 2: f(x)= 1.97525
# differential_evolution step 3: f(x)= 1.97525
# differential_evolution step 4: f(x)= 1.3742
# differential_evolution step 5: f(x)= 1.3742
# differential_evolution step 6: f(x)= 1.3742
# differential_evolution step 7: f(x)= 0.83524
# differential_evolution step 8: f(x)= 0.657377
# differential_evolution step 9: f(x)= 0.657377
# differential_evolution step 10: f(x)= 0.657377
# differential_evolution step 11: f(x)= 0.657377
# differential_evolution step 12: f(x)= 0.657377
# differential_evolution step 13: f(x)= 0.657377
# differential_evolution step 14: f(x)= 0.657377
# differential_evolution step 15: f(x)= 0.657377
# differential_evolution step 16: f(x)= 0.652796
# differential_evolution step 17: f(x)= 0.563638
# differential_evolution step 18: f(x)= 0.563638
# differential_evolution step 19: f(x)= 0.511279
# differential_evolution step 20: f(x)= 0.502534
# differential_evolution step 21: f(x)= 0.502534
# differential_evolution step 22: f(x)= 0.502534
# differential_evolution step 23: f(x)= 0.502534
# differential_evolution step 24: f(x)= 0.487089
# differential_evolution step 25: f(x)= 0.487089
# differential_evolution step 26: f(x)= 0.487089
# differential_evolution step 27: f(x)= 0.487089
# differential_evolution step 28: f(x)= 0.487089
# differential_evolution step 29: f(x)= 0.487089
# differential_evolution step 30: f(x)= 0.487089
# differential_evolution step 31: f(x)= 0.479495
# differential_evolution step 32: f(x)= 0.479495
# differential_evolution step 33: f(x)= 0.479495
# differential_evolution step 34: f(x)= 0.479495
# differential_evolution step 35: f(x)= 0.448675
# differential_evolution step 36: f(x)= 0.448675
# differential_evolution step 37: f(x)= 0.448675
# differential_evolution step 38: f(x)= 0.44237
# differential_evolution step 39: f(x)= 0.44237
# differential_evolution step 40: f(x)= 0.44237
# differential_evolution step 41: f(x)= 0.44237
# differential_evolution step 42: f(x)= 0.44237
# differential_evolution step 43: f(x)= 0.44237
# differential_evolution step 44: f(x)= 0.44237
# differential_evolution step 45: f(x)= 0.44237
# differential_evolution step 46: f(x)= 0.44237
# differential_evolution step 47: f(x)= 0.44237
# differential_evolution step 48: f(x)= 0.44237
# differential_evolution step 49: f(x)= 0.44237
# differential_evolution step 50: f(x)= 0.44237
# differential_evolution step 51: f(x)= 0.44237
# differential_evolution step 52: f(x)= 0.44237
# differential_evolution step 53: f(x)= 0.44237
# differential_evolution step 54: f(x)= 0.44237
# differential_evolution step 55: f(x)= 0.44237
# differential_evolution step 56: f(x)= 0.44237
# differential_evolution step 57: f(x)= 0.44237
# differential_evolution step 58: f(x)= 0.44237
# differential_evolution step 59: f(x)= 0.44237
# differential_evolution step 60: f(x)= 0.44237
# differential_evolution step 61: f(x)= 0.44237
# differential_evolution step 62: f(x)= 0.44237
# differential_evolution step 63: f(x)= 0.44237
# differential_evolution step 64: f(x)= 0.44237
# differential_evolution step 65: f(x)= 0.44237
# differential_evolution step 66: f(x)= 0.44237
# differential_evolution step 67: f(x)= 0.44237
# differential_evolution step 68: f(x)= 0.442301
# differential_evolution step 69: f(x)= 0.442301
# differential_evolution step 70: f(x)= 0.442301
# differential_evolution step 71: f(x)= 0.441675
# differential_evolution step 72: f(x)= 0.441205
# differential_evolution step 73: f(x)= 0.441205
# differential_evolution step 74: f(x)= 0.441205
# differential_evolution step 75: f(x)= 0.441205
# differential_evolution step 76: f(x)= 0.441205
# differential_evolution step 77: f(x)= 0.441205
# differential_evolution step 78: f(x)= 0.441205
# differential_evolution step 79: f(x)= 0.441205
# differential_evolution step 80: f(x)= 0.441205
# differential_evolution step 81: f(x)= 0.441205
# differential_evolution step 82: f(x)= 0.441205
# differential_evolution step 83: f(x)= 0.441205
# differential_evolution step 84: f(x)= 0.440385
# Params [1.48195949e+00 3.85726278e+00 2.01608485e-02 1.49532853e+02
#  1.39123250e+00 9.33349602e-01 3.69892941e-01 8.39208509e-02] gave 0.4396380082977528
# 129
# differential_evolution step 1: f(x)= 1.66642
# differential_evolution step 2: f(x)= 1.01384
# differential_evolution step 3: f(x)= 1.01384
# differential_evolution step 4: f(x)= 1.01384
# differential_evolution step 5: f(x)= 1.01384
# differential_evolution step 6: f(x)= 0.764938
# differential_evolution step 7: f(x)= 0.764938
# differential_evolution step 8: f(x)= 0.70937
# differential_evolution step 9: f(x)= 0.70937
# differential_evolution step 10: f(x)= 0.70937
# differential_evolution step 11: f(x)= 0.70937
# differential_evolution step 12: f(x)= 0.70937
# differential_evolution step 13: f(x)= 0.70937
# differential_evolution step 14: f(x)= 0.692305
# differential_evolution step 15: f(x)= 0.586543
# differential_evolution step 16: f(x)= 0.586543
# differential_evolution step 17: f(x)= 0.569975
# differential_evolution step 18: f(x)= 0.543164
# differential_evolution step 19: f(x)= 0.543164
# differential_evolution step 20: f(x)= 0.543164
# differential_evolution step 21: f(x)= 0.543164
# differential_evolution step 22: f(x)= 0.541106
# differential_evolution step 23: f(x)= 0.53608
# differential_evolution step 24: f(x)= 0.529362
# differential_evolution step 25: f(x)= 0.487773
# differential_evolution step 26: f(x)= 0.484228
# differential_evolution step 27: f(x)= 0.484228
# differential_evolution step 28: f(x)= 0.484228
# differential_evolution step 29: f(x)= 0.484228
# differential_evolution step 30: f(x)= 0.484228
# differential_evolution step 31: f(x)= 0.483315
# differential_evolution step 32: f(x)= 0.456148
# differential_evolution step 33: f(x)= 0.456148
# differential_evolution step 34: f(x)= 0.45553
# differential_evolution step 35: f(x)= 0.45553
# differential_evolution step 36: f(x)= 0.45553
# differential_evolution step 37: f(x)= 0.453206
# differential_evolution step 38: f(x)= 0.453206
# differential_evolution step 39: f(x)= 0.453206
# differential_evolution step 40: f(x)= 0.453206
# differential_evolution step 41: f(x)= 0.453206
# differential_evolution step 42: f(x)= 0.453206
# differential_evolution step 43: f(x)= 0.451632
# differential_evolution step 44: f(x)= 0.449741
# differential_evolution step 45: f(x)= 0.447158
# differential_evolution step 46: f(x)= 0.445357
# differential_evolution step 47: f(x)= 0.445357
# differential_evolution step 48: f(x)= 0.445357
# differential_evolution step 49: f(x)= 0.445357
# differential_evolution step 50: f(x)= 0.445357
# differential_evolution step 51: f(x)= 0.445357
# differential_evolution step 52: f(x)= 0.442864
# differential_evolution step 53: f(x)= 0.442864
# differential_evolution step 54: f(x)= 0.441717
# differential_evolution step 55: f(x)= 0.441717
# differential_evolution step 56: f(x)= 0.441717
# differential_evolution step 57: f(x)= 0.441717
# differential_evolution step 58: f(x)= 0.441717
# differential_evolution step 59: f(x)= 0.441717
# differential_evolution step 60: f(x)= 0.441572
# differential_evolution step 61: f(x)= 0.441572
# differential_evolution step 62: f(x)= 0.441572
# differential_evolution step 63: f(x)= 0.441354
# differential_evolution step 64: f(x)= 0.441354
# differential_evolution step 65: f(x)= 0.441354
# differential_evolution step 66: f(x)= 0.441354
# differential_evolution step 67: f(x)= 0.441354
# differential_evolution step 68: f(x)= 0.439641
# differential_evolution step 69: f(x)= 0.439641
# differential_evolution step 70: f(x)= 0.439641
# differential_evolution step 71: f(x)= 0.439641
# differential_evolution step 72: f(x)= 0.439641
# differential_evolution step 73: f(x)= 0.439641
# differential_evolution step 74: f(x)= 0.439315
# differential_evolution step 75: f(x)= 0.439315
# differential_evolution step 76: f(x)= 0.439315
# differential_evolution step 77: f(x)= 0.439315
# differential_evolution step 78: f(x)= 0.439315
# differential_evolution step 79: f(x)= 0.439315
# differential_evolution step 80: f(x)= 0.439315
# differential_evolution step 81: f(x)= 0.439315
# differential_evolution step 82: f(x)= 0.439315
# differential_evolution step 83: f(x)= 0.439315
# Warning: optimizer went out of bounds.  Setting 1.000000 to 1.000000
# Params [1.48279225e+00 3.88920424e+00 2.00165694e-02 1.47671522e+02
#  1.40255290e+00 1.04086208e+00 3.59520396e-01 5.64734943e-04] gave 0.439315013023788
# 129
# differential_evolution step 1: f(x)= 2.86553
# differential_evolution step 2: f(x)= 0.666733
# differential_evolution step 3: f(x)= 0.666733
# differential_evolution step 4: f(x)= 0.666733
# differential_evolution step 5: f(x)= 0.666733
# differential_evolution step 6: f(x)= 0.666733
# differential_evolution step 7: f(x)= 0.640627
# differential_evolution step 8: f(x)= 0.611465
# differential_evolution step 9: f(x)= 0.611465
# differential_evolution step 10: f(x)= 0.611465
# differential_evolution step 11: f(x)= 0.611465
# differential_evolution step 12: f(x)= 0.516055
# differential_evolution step 13: f(x)= 0.516055
# differential_evolution step 14: f(x)= 0.502999
# differential_evolution step 15: f(x)= 0.494738
# differential_evolution step 16: f(x)= 0.494738
# differential_evolution step 17: f(x)= 0.490901
# differential_evolution step 18: f(x)= 0.490901
# differential_evolution step 19: f(x)= 0.490901
# differential_evolution step 20: f(x)= 0.490901
# differential_evolution step 21: f(x)= 0.490901
# differential_evolution step 22: f(x)= 0.478061
# differential_evolution step 23: f(x)= 0.463272
# differential_evolution step 24: f(x)= 0.459233
# differential_evolution step 25: f(x)= 0.459233
# differential_evolution step 26: f(x)= 0.459233
# differential_evolution step 27: f(x)= 0.459233
# differential_evolution step 28: f(x)= 0.459233
# differential_evolution step 29: f(x)= 0.455086
# differential_evolution step 30: f(x)= 0.455086
# differential_evolution step 31: f(x)= 0.455086
# differential_evolution step 32: f(x)= 0.455086
# differential_evolution step 33: f(x)= 0.455086
# differential_evolution step 34: f(x)= 0.455086
# differential_evolution step 35: f(x)= 0.451544
# differential_evolution step 36: f(x)= 0.451544
# differential_evolution step 37: f(x)= 0.451544
# differential_evolution step 38: f(x)= 0.443416
# differential_evolution step 39: f(x)= 0.443416
# differential_evolution step 40: f(x)= 0.442177
# differential_evolution step 41: f(x)= 0.442177
# differential_evolution step 42: f(x)= 0.442177
# differential_evolution step 43: f(x)= 0.442177
# differential_evolution step 44: f(x)= 0.442177
# differential_evolution step 45: f(x)= 0.442177
# differential_evolution step 46: f(x)= 0.441095
# differential_evolution step 47: f(x)= 0.441095
# differential_evolution step 48: f(x)= 0.441095
# differential_evolution step 49: f(x)= 0.441095
# differential_evolution step 50: f(x)= 0.441095
# differential_evolution step 51: f(x)= 0.441095
# differential_evolution step 52: f(x)= 0.439885
# differential_evolution step 53: f(x)= 0.439885
# differential_evolution step 54: f(x)= 0.439606
# differential_evolution step 55: f(x)= 0.439606
# differential_evolution step 56: f(x)= 0.439606
# differential_evolution step 57: f(x)= 0.439575
# differential_evolution step 58: f(x)= 0.439575
# differential_evolution step 59: f(x)= 0.43928
# differential_evolution step 60: f(x)= 0.438693
# differential_evolution step 61: f(x)= 0.438693
# differential_evolution step 62: f(x)= 0.438461
# differential_evolution step 63: f(x)= 0.438461
# Params [1.49705928e+00 3.86992881e+00 1.97829653e-02 1.49365968e+02
#  1.38939667e+00 1.03423717e+00 3.58651454e-01 2.96815314e-02] gave 0.43810336688676665
# 129
# differential_evolution step 1: f(x)= 1.64233
# differential_evolution step 2: f(x)= 1.30465
# differential_evolution step 3: f(x)= 1.30465
# differential_evolution step 4: f(x)= 1.30465
# differential_evolution step 5: f(x)= 0.829788
# differential_evolution step 6: f(x)= 0.829788
# differential_evolution step 7: f(x)= 0.818555
# differential_evolution step 8: f(x)= 0.818555
# differential_evolution step 9: f(x)= 0.818555
# differential_evolution step 10: f(x)= 0.818555
# differential_evolution step 11: f(x)= 0.640985
# differential_evolution step 12: f(x)= 0.640985
# differential_evolution step 13: f(x)= 0.640985
# differential_evolution step 14: f(x)= 0.496084
# differential_evolution step 15: f(x)= 0.496084
# differential_evolution step 16: f(x)= 0.496084
# differential_evolution step 17: f(x)= 0.496084
# differential_evolution step 18: f(x)= 0.496084
# differential_evolution step 19: f(x)= 0.496084
# differential_evolution step 20: f(x)= 0.496084
# differential_evolution step 21: f(x)= 0.496084
# differential_evolution step 22: f(x)= 0.496084
# differential_evolution step 23: f(x)= 0.493692
# differential_evolution step 24: f(x)= 0.493692
# differential_evolution step 25: f(x)= 0.483127
# differential_evolution step 26: f(x)= 0.476164
# differential_evolution step 27: f(x)= 0.476164
# differential_evolution step 28: f(x)= 0.476164
# differential_evolution step 29: f(x)= 0.465121
# differential_evolution step 30: f(x)= 0.458692
# differential_evolution step 31: f(x)= 0.458692
# differential_evolution step 32: f(x)= 0.458692
# differential_evolution step 33: f(x)= 0.450456
# differential_evolution step 34: f(x)= 0.450456
# differential_evolution step 35: f(x)= 0.450456
# differential_evolution step 36: f(x)= 0.448519
# differential_evolution step 37: f(x)= 0.448519
# differential_evolution step 38: f(x)= 0.448519
# differential_evolution step 39: f(x)= 0.448519
# differential_evolution step 40: f(x)= 0.448519
# differential_evolution step 41: f(x)= 0.448519
# differential_evolution step 42: f(x)= 0.448519
# differential_evolution step 43: f(x)= 0.448519
# differential_evolution step 44: f(x)= 0.448081
# differential_evolution step 45: f(x)= 0.448081
# differential_evolution step 46: f(x)= 0.444217
# differential_evolution step 47: f(x)= 0.443588
# differential_evolution step 48: f(x)= 0.443588
# differential_evolution step 49: f(x)= 0.441769
# differential_evolution step 50: f(x)= 0.441769
# differential_evolution step 51: f(x)= 0.441769
# differential_evolution step 52: f(x)= 0.441769
# differential_evolution step 53: f(x)= 0.441769
# differential_evolution step 54: f(x)= 0.441769
# differential_evolution step 55: f(x)= 0.441769
# differential_evolution step 56: f(x)= 0.441769
# differential_evolution step 57: f(x)= 0.441769
# differential_evolution step 58: f(x)= 0.440728
# differential_evolution step 59: f(x)= 0.440728
# differential_evolution step 60: f(x)= 0.440728
# differential_evolution step 61: f(x)= 0.43982
# differential_evolution step 62: f(x)= 0.43982
# differential_evolution step 63: f(x)= 0.43982
# differential_evolution step 64: f(x)= 0.43982
# differential_evolution step 65: f(x)= 0.43982
# differential_evolution step 66: f(x)= 0.43982
# Warning: optimizer went out of bounds.  Setting 1.000000 to 1.000000
# Params [1.48880272e+00 3.91631119e+00 2.00701640e-02 1.46409576e+02
#  1.43135360e+00 9.18177930e-01 3.63926251e-01 1.37825982e-02] gave 0.4394304133124572
# 129
# differential_evolution step 1: f(x)= 2.77669
# differential_evolution step 2: f(x)= 1.34351
# differential_evolution step 3: f(x)= 1.00213
# differential_evolution step 4: f(x)= 1.00213
# differential_evolution step 5: f(x)= 1.00213
# differential_evolution step 6: f(x)= 1.00213
# differential_evolution step 7: f(x)= 1.00213
# differential_evolution step 8: f(x)= 0.747858
# differential_evolution step 9: f(x)= 0.681669
# differential_evolution step 10: f(x)= 0.681669
# differential_evolution step 11: f(x)= 0.681669
# differential_evolution step 12: f(x)= 0.681669
# differential_evolution step 13: f(x)= 0.58401
# differential_evolution step 14: f(x)= 0.58401
# differential_evolution step 15: f(x)= 0.569565
# differential_evolution step 16: f(x)= 0.569565
# differential_evolution step 17: f(x)= 0.569565
# differential_evolution step 18: f(x)= 0.569565
# differential_evolution step 19: f(x)= 0.566837
# differential_evolution step 20: f(x)= 0.548568
# differential_evolution step 21: f(x)= 0.548568
# differential_evolution step 22: f(x)= 0.505298
# differential_evolution step 23: f(x)= 0.505298
# differential_evolution step 24: f(x)= 0.505298
# differential_evolution step 25: f(x)= 0.470684
# differential_evolution step 26: f(x)= 0.470684
# differential_evolution step 27: f(x)= 0.465906
# differential_evolution step 28: f(x)= 0.465906
# differential_evolution step 29: f(x)= 0.46319
# differential_evolution step 30: f(x)= 0.46319
# differential_evolution step 31: f(x)= 0.452768
# differential_evolution step 32: f(x)= 0.452768
# differential_evolution step 33: f(x)= 0.452768
# differential_evolution step 34: f(x)= 0.452768
# differential_evolution step 35: f(x)= 0.452768
# differential_evolution step 36: f(x)= 0.452768
# differential_evolution step 37: f(x)= 0.452768
# differential_evolution step 38: f(x)= 0.452768
# differential_evolution step 39: f(x)= 0.452768
# differential_evolution step 40: f(x)= 0.452768
# differential_evolution step 41: f(x)= 0.452768
# differential_evolution step 42: f(x)= 0.452768
# differential_evolution step 43: f(x)= 0.452768
# differential_evolution step 44: f(x)= 0.447669
# differential_evolution step 45: f(x)= 0.444001
# differential_evolution step 46: f(x)= 0.444001
# differential_evolution step 47: f(x)= 0.444001
# differential_evolution step 48: f(x)= 0.444001
# differential_evolution step 49: f(x)= 0.443496
# differential_evolution step 50: f(x)= 0.443496
# differential_evolution step 51: f(x)= 0.443496
# differential_evolution step 52: f(x)= 0.443496
# differential_evolution step 53: f(x)= 0.443496
# differential_evolution step 54: f(x)= 0.44125
# differential_evolution step 55: f(x)= 0.44125
# differential_evolution step 56: f(x)= 0.44125
# differential_evolution step 57: f(x)= 0.439957
# differential_evolution step 58: f(x)= 0.439957
# differential_evolution step 59: f(x)= 0.439957
# differential_evolution step 60: f(x)= 0.439957
# differential_evolution step 61: f(x)= 0.439957
# differential_evolution step 62: f(x)= 0.439957
# differential_evolution step 63: f(x)= 0.439957
# differential_evolution step 64: f(x)= 0.439957
# differential_evolution step 65: f(x)= 0.439957
# differential_evolution step 66: f(x)= 0.439957
# differential_evolution step 67: f(x)= 0.439957
# differential_evolution step 68: f(x)= 0.439957
# differential_evolution step 69: f(x)= 0.439742
# differential_evolution step 70: f(x)= 0.439372
# differential_evolution step 71: f(x)= 0.439372
# differential_evolution step 72: f(x)= 0.439372
# differential_evolution step 73: f(x)= 0.43936
# differential_evolution step 74: f(x)= 0.43936
# differential_evolution step 75: f(x)= 0.439196
# differential_evolution step 76: f(x)= 0.439196
# differential_evolution step 77: f(x)= 0.439196
# differential_evolution step 78: f(x)= 0.439196
# differential_evolution step 79: f(x)= 0.439196
# Warning: optimizer went out of bounds.  Setting 1.000000 to 1.000000
# Params [1.50868953e+00 3.82182988e+00 2.02236254e-02 1.49946827e+02
#  1.40063209e+00 1.03244192e+00 3.50161417e-01 6.43075871e-02] gave 0.4391964819616919
# 389
# differential_evolution step 1: f(x)= 0.915836
# differential_evolution step 2: f(x)= 0.915836
# differential_evolution step 3: f(x)= 0.905739
# differential_evolution step 4: f(x)= 0.905739
# differential_evolution step 5: f(x)= 0.905739
# differential_evolution step 6: f(x)= 0.38291
# differential_evolution step 7: f(x)= 0.38291
# differential_evolution step 8: f(x)= 0.38291
# differential_evolution step 9: f(x)= 0.38291
# differential_evolution step 10: f(x)= 0.38291
# differential_evolution step 11: f(x)= 0.38291
# differential_evolution step 12: f(x)= 0.38291
# differential_evolution step 13: f(x)= 0.38291
# differential_evolution step 14: f(x)= 0.38291
# differential_evolution step 15: f(x)= 0.38291
# differential_evolution step 16: f(x)= 0.38291
# differential_evolution step 17: f(x)= 0.38291
# differential_evolution step 18: f(x)= 0.38291
# differential_evolution step 19: f(x)= 0.38291
# differential_evolution step 20: f(x)= 0.38291
# differential_evolution step 21: f(x)= 0.367407
# differential_evolution step 22: f(x)= 0.367407
# differential_evolution step 23: f(x)= 0.367407
# differential_evolution step 24: f(x)= 0.367407
# differential_evolution step 25: f(x)= 0.353531
# differential_evolution step 26: f(x)= 0.352468
# differential_evolution step 27: f(x)= 0.345127
# differential_evolution step 28: f(x)= 0.345127
# differential_evolution step 29: f(x)= 0.345127
# differential_evolution step 30: f(x)= 0.345127
# differential_evolution step 31: f(x)= 0.345127
# differential_evolution step 32: f(x)= 0.345127
# differential_evolution step 33: f(x)= 0.328073
# differential_evolution step 34: f(x)= 0.328073
# differential_evolution step 35: f(x)= 0.328073
# differential_evolution step 36: f(x)= 0.328073
# differential_evolution step 37: f(x)= 0.328073
# differential_evolution step 38: f(x)= 0.328073
# differential_evolution step 39: f(x)= 0.328073
# differential_evolution step 40: f(x)= 0.326688
# differential_evolution step 41: f(x)= 0.325865
# differential_evolution step 42: f(x)= 0.322399
# differential_evolution step 43: f(x)= 0.322049
# differential_evolution step 44: f(x)= 0.322049
# differential_evolution step 45: f(x)= 0.322049
# differential_evolution step 46: f(x)= 0.322049
# differential_evolution step 47: f(x)= 0.322049
# differential_evolution step 48: f(x)= 0.322049
# differential_evolution step 49: f(x)= 0.321504
# differential_evolution step 50: f(x)= 0.321504
# differential_evolution step 51: f(x)= 0.321504
# differential_evolution step 52: f(x)= 0.321504
# differential_evolution step 53: f(x)= 0.321504
# differential_evolution step 54: f(x)= 0.31846
# differential_evolution step 55: f(x)= 0.31846
# differential_evolution step 56: f(x)= 0.31846
# differential_evolution step 57: f(x)= 0.318372
# differential_evolution step 58: f(x)= 0.318372
# differential_evolution step 59: f(x)= 0.317633
# differential_evolution step 60: f(x)= 0.317633
# differential_evolution step 61: f(x)= 0.315245
# differential_evolution step 62: f(x)= 0.315245
# differential_evolution step 63: f(x)= 0.315245
# differential_evolution step 64: f(x)= 0.313413
# differential_evolution step 65: f(x)= 0.313413
# differential_evolution step 66: f(x)= 0.313413
# differential_evolution step 67: f(x)= 0.312793
# differential_evolution step 68: f(x)= 0.312793
# differential_evolution step 69: f(x)= 0.312793
# differential_evolution step 70: f(x)= 0.312793
# differential_evolution step 71: f(x)= 0.312793
# differential_evolution step 72: f(x)= 0.312793
# differential_evolution step 73: f(x)= 0.312793
# differential_evolution step 74: f(x)= 0.312793
# differential_evolution step 75: f(x)= 0.312793
# differential_evolution step 76: f(x)= 0.312793
# differential_evolution step 77: f(x)= 0.312793
# differential_evolution step 78: f(x)= 0.312793
# differential_evolution step 79: f(x)= 0.312025
# differential_evolution step 80: f(x)= 0.312025
# differential_evolution step 81: f(x)= 0.312025
# differential_evolution step 82: f(x)= 0.312025
# differential_evolution step 83: f(x)= 0.312025
# differential_evolution step 84: f(x)= 0.312025
# differential_evolution step 85: f(x)= 0.312025
# differential_evolution step 86: f(x)= 0.312025
# differential_evolution step 87: f(x)= 0.312025
# differential_evolution step 88: f(x)= 0.312025
# differential_evolution step 89: f(x)= 0.312025
# differential_evolution step 90: f(x)= 0.312025
# differential_evolution step 91: f(x)= 0.312025
# differential_evolution step 92: f(x)= 0.312025
# differential_evolution step 93: f(x)= 0.312025
# Params [1.62397552e+00 4.20690465e+00 5.36837062e-02 1.42185596e+02
#  7.68257264e-01 1.00950860e-01 4.95471655e-01 1.70100855e-01] gave 0.31202528034828253
# 389
# differential_evolution step 1: f(x)= 0.840168
# differential_evolution step 2: f(x)= 0.840168
# differential_evolution step 3: f(x)= 0.721714
# differential_evolution step 4: f(x)= 0.721714
# differential_evolution step 5: f(x)= 0.721714
# differential_evolution step 6: f(x)= 0.721714
# differential_evolution step 7: f(x)= 0.592654
# differential_evolution step 8: f(x)= 0.592654
# differential_evolution step 9: f(x)= 0.483343
# differential_evolution step 10: f(x)= 0.376762
# differential_evolution step 11: f(x)= 0.376762
# differential_evolution step 12: f(x)= 0.376762
# differential_evolution step 13: f(x)= 0.376762
# differential_evolution step 14: f(x)= 0.376762
# differential_evolution step 15: f(x)= 0.376762
# differential_evolution step 16: f(x)= 0.366492
# differential_evolution step 17: f(x)= 0.366492
# differential_evolution step 18: f(x)= 0.366492
# differential_evolution step 19: f(x)= 0.366492
# differential_evolution step 20: f(x)= 0.366492
# differential_evolution step 21: f(x)= 0.366492
# differential_evolution step 22: f(x)= 0.366492
# differential_evolution step 23: f(x)= 0.366492
# differential_evolution step 24: f(x)= 0.366492
# differential_evolution step 25: f(x)= 0.346769
# differential_evolution step 26: f(x)= 0.342203
# differential_evolution step 27: f(x)= 0.342203
# differential_evolution step 28: f(x)= 0.341251
# differential_evolution step 29: f(x)= 0.33531
# differential_evolution step 30: f(x)= 0.33531
# differential_evolution step 31: f(x)= 0.33531
# differential_evolution step 32: f(x)= 0.333249
# differential_evolution step 33: f(x)= 0.333249
# differential_evolution step 34: f(x)= 0.32707
# differential_evolution step 35: f(x)= 0.32707
# differential_evolution step 36: f(x)= 0.322435
# differential_evolution step 37: f(x)= 0.322435
# differential_evolution step 38: f(x)= 0.322435
# differential_evolution step 39: f(x)= 0.322435
# differential_evolution step 40: f(x)= 0.322435
# differential_evolution step 41: f(x)= 0.322435
# differential_evolution step 42: f(x)= 0.322435
# differential_evolution step 43: f(x)= 0.322435
# differential_evolution step 44: f(x)= 0.322435
# differential_evolution step 45: f(x)= 0.322435
# differential_evolution step 46: f(x)= 0.322435
# differential_evolution step 47: f(x)= 0.322435
# differential_evolution step 48: f(x)= 0.318822
# differential_evolution step 49: f(x)= 0.318822
# differential_evolution step 50: f(x)= 0.318822
# differential_evolution step 51: f(x)= 0.318822
# differential_evolution step 52: f(x)= 0.318822
# differential_evolution step 53: f(x)= 0.318822
# differential_evolution step 54: f(x)= 0.318822
# differential_evolution step 55: f(x)= 0.318822
# differential_evolution step 56: f(x)= 0.318822
# differential_evolution step 57: f(x)= 0.318822
# differential_evolution step 58: f(x)= 0.318822
# differential_evolution step 59: f(x)= 0.318509
# differential_evolution step 60: f(x)= 0.318049
# differential_evolution step 61: f(x)= 0.315856
# differential_evolution step 62: f(x)= 0.315856
# differential_evolution step 63: f(x)= 0.313499
# differential_evolution step 64: f(x)= 0.313499
# differential_evolution step 65: f(x)= 0.313499
# differential_evolution step 66: f(x)= 0.313499
# differential_evolution step 67: f(x)= 0.313499
# differential_evolution step 68: f(x)= 0.313499
# differential_evolution step 69: f(x)= 0.313499
# differential_evolution step 70: f(x)= 0.313499
# differential_evolution step 71: f(x)= 0.313499
# differential_evolution step 72: f(x)= 0.313499
# differential_evolution step 73: f(x)= 0.313401
# differential_evolution step 74: f(x)= 0.313401
# differential_evolution step 75: f(x)= 0.313401
# differential_evolution step 76: f(x)= 0.313401
# differential_evolution step 77: f(x)= 0.313401
# differential_evolution step 78: f(x)= 0.313401
# differential_evolution step 79: f(x)= 0.313401
# differential_evolution step 80: f(x)= 0.313401
# differential_evolution step 81: f(x)= 0.313401
# differential_evolution step 82: f(x)= 0.313401
# differential_evolution step 83: f(x)= 0.313401
# differential_evolution step 84: f(x)= 0.313401
# differential_evolution step 85: f(x)= 0.313401
# differential_evolution step 86: f(x)= 0.313401
# differential_evolution step 87: f(x)= 0.313074
# differential_evolution step 88: f(x)= 0.313074
# differential_evolution step 89: f(x)= 0.313074
# differential_evolution step 90: f(x)= 0.31225
# differential_evolution step 91: f(x)= 0.31225
# differential_evolution step 92: f(x)= 0.31225
# differential_evolution step 93: f(x)= 0.31225
# differential_evolution step 94: f(x)= 0.31225
# differential_evolution step 95: f(x)= 0.31225
# Params [1.60256332e+00 5.89797428e+00 5.30684178e-02 1.09966881e+02
#  8.77626191e-01 1.05563322e-01 4.98935825e-01 1.72473920e-01] gave 0.3121995580437918
# 389
# differential_evolution step 1: f(x)= 1.67389
# differential_evolution step 2: f(x)= 1.67389
# differential_evolution step 3: f(x)= 1.65231
# differential_evolution step 4: f(x)= 1.37885
# differential_evolution step 5: f(x)= 0.751926
# differential_evolution step 6: f(x)= 0.751926
# differential_evolution step 7: f(x)= 0.702336
# differential_evolution step 8: f(x)= 0.599417
# differential_evolution step 9: f(x)= 0.575217
# differential_evolution step 10: f(x)= 0.575217
# differential_evolution step 11: f(x)= 0.449559
# differential_evolution step 12: f(x)= 0.440188
# differential_evolution step 13: f(x)= 0.440188
# differential_evolution step 14: f(x)= 0.440188
# differential_evolution step 15: f(x)= 0.338089
# differential_evolution step 16: f(x)= 0.338089
# differential_evolution step 17: f(x)= 0.338089
# differential_evolution step 18: f(x)= 0.338089
# differential_evolution step 19: f(x)= 0.338089
# differential_evolution step 20: f(x)= 0.338089
# differential_evolution step 21: f(x)= 0.338089
# differential_evolution step 22: f(x)= 0.326298
# differential_evolution step 23: f(x)= 0.326298
# differential_evolution step 24: f(x)= 0.326298
# differential_evolution step 25: f(x)= 0.326298
# differential_evolution step 26: f(x)= 0.326298
# differential_evolution step 27: f(x)= 0.326298
# differential_evolution step 28: f(x)= 0.326298
# differential_evolution step 29: f(x)= 0.326298
# differential_evolution step 30: f(x)= 0.326298
# differential_evolution step 31: f(x)= 0.326298
# differential_evolution step 32: f(x)= 0.326298
# differential_evolution step 33: f(x)= 0.326298
# differential_evolution step 34: f(x)= 0.326298
# differential_evolution step 35: f(x)= 0.326298
# differential_evolution step 36: f(x)= 0.326186
# differential_evolution step 37: f(x)= 0.320611
# differential_evolution step 38: f(x)= 0.320611
# differential_evolution step 39: f(x)= 0.320611
# differential_evolution step 40: f(x)= 0.320611
# differential_evolution step 41: f(x)= 0.320611
# differential_evolution step 42: f(x)= 0.320611
# differential_evolution step 43: f(x)= 0.320611
# differential_evolution step 44: f(x)= 0.320611
# differential_evolution step 45: f(x)= 0.320177
# differential_evolution step 46: f(x)= 0.320177
# differential_evolution step 47: f(x)= 0.320177
# differential_evolution step 48: f(x)= 0.320177
# differential_evolution step 49: f(x)= 0.320177
# differential_evolution step 50: f(x)= 0.320177
# differential_evolution step 51: f(x)= 0.320026
# differential_evolution step 52: f(x)= 0.318098
# differential_evolution step 53: f(x)= 0.316507
# differential_evolution step 54: f(x)= 0.316507
# differential_evolution step 55: f(x)= 0.316507
# differential_evolution step 56: f(x)= 0.316507
# differential_evolution step 57: f(x)= 0.316507
# differential_evolution step 58: f(x)= 0.316507
# differential_evolution step 59: f(x)= 0.316507
# differential_evolution step 60: f(x)= 0.316507
# differential_evolution step 61: f(x)= 0.316507
# differential_evolution step 62: f(x)= 0.316507
# differential_evolution step 63: f(x)= 0.31634
# differential_evolution step 64: f(x)= 0.31634
# differential_evolution step 65: f(x)= 0.31634
# differential_evolution step 66: f(x)= 0.31634
# differential_evolution step 67: f(x)= 0.31611
# differential_evolution step 68: f(x)= 0.315781
# differential_evolution step 69: f(x)= 0.315126
# differential_evolution step 70: f(x)= 0.314959
# differential_evolution step 71: f(x)= 0.314959
# differential_evolution step 72: f(x)= 0.314645
# differential_evolution step 73: f(x)= 0.314645
# differential_evolution step 74: f(x)= 0.313288
# Warning: optimizer went out of bounds.  Setting 1.000000 to 1.000000
# Params [1.62085152e+00 5.95948089e+00 5.24969638e-02 1.09131165e+02
#  8.61524002e-01 1.03272403e-01 4.96553282e-01 1.79922109e-01] gave 0.31328760654849075
# 389
# differential_evolution step 1: f(x)= 1.0647
# differential_evolution step 2: f(x)= 1.0647
# differential_evolution step 3: f(x)= 1.0647
# differential_evolution step 4: f(x)= 1.0647
# differential_evolution step 5: f(x)= 0.592908
# differential_evolution step 6: f(x)= 0.592908
# differential_evolution step 7: f(x)= 0.592908
# differential_evolution step 8: f(x)= 0.592908
# differential_evolution step 9: f(x)= 0.472683
# differential_evolution step 10: f(x)= 0.472683
# differential_evolution step 11: f(x)= 0.452814
# differential_evolution step 12: f(x)= 0.452814
# differential_evolution step 13: f(x)= 0.452814
# differential_evolution step 14: f(x)= 0.452814
# differential_evolution step 15: f(x)= 0.452814
# differential_evolution step 16: f(x)= 0.452814
# differential_evolution step 17: f(x)= 0.452814
# differential_evolution step 18: f(x)= 0.452814
# differential_evolution step 19: f(x)= 0.452814
# differential_evolution step 20: f(x)= 0.452814
# differential_evolution step 21: f(x)= 0.452814
# differential_evolution step 22: f(x)= 0.452814
# differential_evolution step 23: f(x)= 0.440515
# differential_evolution step 24: f(x)= 0.41012
# differential_evolution step 25: f(x)= 0.361074
# differential_evolution step 26: f(x)= 0.361074
# differential_evolution step 27: f(x)= 0.361074
# differential_evolution step 28: f(x)= 0.331798
# differential_evolution step 29: f(x)= 0.331798
# differential_evolution step 30: f(x)= 0.331798
# differential_evolution step 31: f(x)= 0.331798
# differential_evolution step 32: f(x)= 0.331798
# differential_evolution step 33: f(x)= 0.331798
# differential_evolution step 34: f(x)= 0.328435
# differential_evolution step 35: f(x)= 0.328435
# differential_evolution step 36: f(x)= 0.327797
# differential_evolution step 37: f(x)= 0.327797
# differential_evolution step 38: f(x)= 0.327797
# differential_evolution step 39: f(x)= 0.327797
# differential_evolution step 40: f(x)= 0.327797
# differential_evolution step 41: f(x)= 0.32189
# differential_evolution step 42: f(x)= 0.32189
# differential_evolution step 43: f(x)= 0.319485
# differential_evolution step 44: f(x)= 0.319485
# differential_evolution step 45: f(x)= 0.318579
# differential_evolution step 46: f(x)= 0.318579
# differential_evolution step 47: f(x)= 0.318579
# differential_evolution step 48: f(x)= 0.318579
# differential_evolution step 49: f(x)= 0.318579
# differential_evolution step 50: f(x)= 0.316338
# differential_evolution step 51: f(x)= 0.316338
# differential_evolution step 52: f(x)= 0.316338
# differential_evolution step 53: f(x)= 0.316338
# differential_evolution step 54: f(x)= 0.316338
# differential_evolution step 55: f(x)= 0.316338
# differential_evolution step 56: f(x)= 0.316338
# differential_evolution step 57: f(x)= 0.316338
# differential_evolution step 58: f(x)= 0.316338
# differential_evolution step 59: f(x)= 0.316338
# differential_evolution step 60: f(x)= 0.316338
# differential_evolution step 61: f(x)= 0.315241
# differential_evolution step 62: f(x)= 0.315241
# differential_evolution step 63: f(x)= 0.315241
# differential_evolution step 64: f(x)= 0.315241
# differential_evolution step 65: f(x)= 0.315241
# differential_evolution step 66: f(x)= 0.315241
# differential_evolution step 67: f(x)= 0.315241
# differential_evolution step 68: f(x)= 0.315241
# differential_evolution step 69: f(x)= 0.315241
# differential_evolution step 70: f(x)= 0.314097
# differential_evolution step 71: f(x)= 0.314097
# differential_evolution step 72: f(x)= 0.313533
# differential_evolution step 73: f(x)= 0.313533
# differential_evolution step 74: f(x)= 0.31323
# differential_evolution step 75: f(x)= 0.31323
# differential_evolution step 76: f(x)= 0.313194
# differential_evolution step 77: f(x)= 0.313194
# differential_evolution step 78: f(x)= 0.313194
# differential_evolution step 79: f(x)= 0.312814
# differential_evolution step 80: f(x)= 0.312768
# differential_evolution step 81: f(x)= 0.312768
# differential_evolution step 82: f(x)= 0.312768
# differential_evolution step 83: f(x)= 0.312768
# differential_evolution step 84: f(x)= 0.312768
# differential_evolution step 85: f(x)= 0.312768
# differential_evolution step 86: f(x)= 0.312768
# differential_evolution step 87: f(x)= 0.312768
# differential_evolution step 88: f(x)= 0.312768
# differential_evolution step 89: f(x)= 0.312768
# differential_evolution step 90: f(x)= 0.312768
# differential_evolution step 91: f(x)= 0.312768
# differential_evolution step 92: f(x)= 0.312768
# differential_evolution step 93: f(x)= 0.312471
# differential_evolution step 94: f(x)= 0.312471
# differential_evolution step 95: f(x)= 0.312471
# differential_evolution step 96: f(x)= 0.312444
# differential_evolution step 97: f(x)= 0.312444
# differential_evolution step 98: f(x)= 0.312379
# Params [1.57812515e+00 4.67204070e+00 5.36821722e-02 1.33023594e+02
#  8.23794544e-01 1.12026409e-01 4.96475956e-01 1.73226441e-01] gave 0.31237866286201427
# 389
# differential_evolution step 1: f(x)= 1.257
# differential_evolution step 2: f(x)= 1.257
# differential_evolution step 3: f(x)= 0.995148
# differential_evolution step 4: f(x)= 0.995148
# differential_evolution step 5: f(x)= 0.995148
# differential_evolution step 6: f(x)= 0.825069
# differential_evolution step 7: f(x)= 0.472516
# differential_evolution step 8: f(x)= 0.472516
# differential_evolution step 9: f(x)= 0.472516
# differential_evolution step 10: f(x)= 0.472516
# differential_evolution step 11: f(x)= 0.472516
# differential_evolution step 12: f(x)= 0.472516
# differential_evolution step 13: f(x)= 0.472516
# differential_evolution step 14: f(x)= 0.472516
# differential_evolution step 15: f(x)= 0.426773
# differential_evolution step 16: f(x)= 0.426773
# differential_evolution step 17: f(x)= 0.426773
# differential_evolution step 18: f(x)= 0.408419
# differential_evolution step 19: f(x)= 0.408419
# differential_evolution step 20: f(x)= 0.408419
# differential_evolution step 21: f(x)= 0.408419
# differential_evolution step 22: f(x)= 0.365757
# differential_evolution step 23: f(x)= 0.365757
# differential_evolution step 24: f(x)= 0.365757
# differential_evolution step 25: f(x)= 0.365757
# differential_evolution step 26: f(x)= 0.365757
# differential_evolution step 27: f(x)= 0.365757
# differential_evolution step 28: f(x)= 0.365757
# differential_evolution step 29: f(x)= 0.34759
# differential_evolution step 30: f(x)= 0.33998
# differential_evolution step 31: f(x)= 0.33998
# differential_evolution step 32: f(x)= 0.33998
# differential_evolution step 33: f(x)= 0.330066
# differential_evolution step 34: f(x)= 0.330066
# differential_evolution step 35: f(x)= 0.330066
# differential_evolution step 36: f(x)= 0.330066
# differential_evolution step 37: f(x)= 0.330066
# differential_evolution step 38: f(x)= 0.326697
# differential_evolution step 39: f(x)= 0.320347
# differential_evolution step 40: f(x)= 0.320347
# differential_evolution step 41: f(x)= 0.320347
# differential_evolution step 42: f(x)= 0.320347
# differential_evolution step 43: f(x)= 0.320347
# differential_evolution step 44: f(x)= 0.320347
# differential_evolution step 45: f(x)= 0.320347
# differential_evolution step 46: f(x)= 0.320347
# differential_evolution step 47: f(x)= 0.320081
# differential_evolution step 48: f(x)= 0.318709
# differential_evolution step 49: f(x)= 0.318709
# differential_evolution step 50: f(x)= 0.318709
# differential_evolution step 51: f(x)= 0.318709
# differential_evolution step 52: f(x)= 0.318709
# differential_evolution step 53: f(x)= 0.318709
# differential_evolution step 54: f(x)= 0.316818
# differential_evolution step 55: f(x)= 0.316818
# differential_evolution step 56: f(x)= 0.316818
# differential_evolution step 57: f(x)= 0.316444
# differential_evolution step 58: f(x)= 0.316155
# differential_evolution step 59: f(x)= 0.316155
# differential_evolution step 60: f(x)= 0.316155
# differential_evolution step 61: f(x)= 0.316155
# differential_evolution step 62: f(x)= 0.316155
# differential_evolution step 63: f(x)= 0.316155
# differential_evolution step 64: f(x)= 0.315063
# differential_evolution step 65: f(x)= 0.315063
# differential_evolution step 66: f(x)= 0.315063
# differential_evolution step 67: f(x)= 0.315063
# differential_evolution step 68: f(x)= 0.315063
# differential_evolution step 69: f(x)= 0.315063
# differential_evolution step 70: f(x)= 0.315063
# differential_evolution step 71: f(x)= 0.315063
# differential_evolution step 72: f(x)= 0.314912
# differential_evolution step 73: f(x)= 0.313982
# differential_evolution step 74: f(x)= 0.313513
# differential_evolution step 75: f(x)= 0.313513
# differential_evolution step 76: f(x)= 0.313513
# differential_evolution step 77: f(x)= 0.313513
# differential_evolution step 78: f(x)= 0.313128
# differential_evolution step 79: f(x)= 0.313128
# differential_evolution step 80: f(x)= 0.313128
# differential_evolution step 81: f(x)= 0.313128
# differential_evolution step 82: f(x)= 0.313128
# differential_evolution step 83: f(x)= 0.313128
# differential_evolution step 84: f(x)= 0.313128
# differential_evolution step 85: f(x)= 0.313128
# Params [1.49524667e+00 5.39970380e+00 5.42283540e-02 1.19109419e+02
#  8.96729242e-01 1.04746924e-01 4.85189631e-01 1.69019365e-01] gave 0.31312804024817825
# 525
# differential_evolution step 1: f(x)= 1.6045
# differential_evolution step 2: f(x)= 1.50159
# differential_evolution step 3: f(x)= 1.38422
# differential_evolution step 4: f(x)= 1.21943
# differential_evolution step 5: f(x)= 0.626829
# differential_evolution step 6: f(x)= 0.626829
# differential_evolution step 7: f(x)= 0.626829
# differential_evolution step 8: f(x)= 0.558848
# differential_evolution step 9: f(x)= 0.493902
# differential_evolution step 10: f(x)= 0.493902
# differential_evolution step 11: f(x)= 0.493902
# differential_evolution step 12: f(x)= 0.416926
# differential_evolution step 13: f(x)= 0.416926
# differential_evolution step 14: f(x)= 0.416926
# differential_evolution step 15: f(x)= 0.416926
# differential_evolution step 16: f(x)= 0.416926
# differential_evolution step 17: f(x)= 0.363032
# differential_evolution step 18: f(x)= 0.333001
# differential_evolution step 19: f(x)= 0.333001
# differential_evolution step 20: f(x)= 0.333001
# differential_evolution step 21: f(x)= 0.270213
# differential_evolution step 22: f(x)= 0.270213
# differential_evolution step 23: f(x)= 0.270213
# differential_evolution step 24: f(x)= 0.263751
# differential_evolution step 25: f(x)= 0.263751
# differential_evolution step 26: f(x)= 0.263751
# differential_evolution step 27: f(x)= 0.257857
# differential_evolution step 28: f(x)= 0.257857
# differential_evolution step 29: f(x)= 0.257857
# differential_evolution step 30: f(x)= 0.257857
# differential_evolution step 31: f(x)= 0.257857
# differential_evolution step 32: f(x)= 0.257857
# differential_evolution step 33: f(x)= 0.249823
# differential_evolution step 34: f(x)= 0.243379
# differential_evolution step 35: f(x)= 0.242398
# differential_evolution step 36: f(x)= 0.242398
# differential_evolution step 37: f(x)= 0.234347
# differential_evolution step 38: f(x)= 0.234347
# differential_evolution step 39: f(x)= 0.234347
# differential_evolution step 40: f(x)= 0.234347
# differential_evolution step 41: f(x)= 0.234347
# differential_evolution step 42: f(x)= 0.234347
# differential_evolution step 43: f(x)= 0.234347
# differential_evolution step 44: f(x)= 0.234347
# differential_evolution step 45: f(x)= 0.234347
# differential_evolution step 46: f(x)= 0.234347
# differential_evolution step 47: f(x)= 0.234347
# differential_evolution step 48: f(x)= 0.234347
# differential_evolution step 49: f(x)= 0.232685
# differential_evolution step 50: f(x)= 0.23144
# differential_evolution step 51: f(x)= 0.23144
# differential_evolution step 52: f(x)= 0.23144
# differential_evolution step 53: f(x)= 0.229884
# differential_evolution step 54: f(x)= 0.229884
# differential_evolution step 55: f(x)= 0.229884
# differential_evolution step 56: f(x)= 0.229884
# differential_evolution step 57: f(x)= 0.226223
# differential_evolution step 58: f(x)= 0.226223
# differential_evolution step 59: f(x)= 0.226223
# differential_evolution step 60: f(x)= 0.226223
# differential_evolution step 61: f(x)= 0.226223
# differential_evolution step 62: f(x)= 0.226223
# differential_evolution step 63: f(x)= 0.226223
# differential_evolution step 64: f(x)= 0.226223
# differential_evolution step 65: f(x)= 0.226223
# differential_evolution step 66: f(x)= 0.226223
# differential_evolution step 67: f(x)= 0.226223
# differential_evolution step 68: f(x)= 0.226223
# differential_evolution step 69: f(x)= 0.226223
# differential_evolution step 70: f(x)= 0.226223
# differential_evolution step 71: f(x)= 0.225147
# differential_evolution step 72: f(x)= 0.225119
# differential_evolution step 73: f(x)= 0.225119
# differential_evolution step 74: f(x)= 0.225119
# differential_evolution step 75: f(x)= 0.225119
# differential_evolution step 76: f(x)= 0.225119
# differential_evolution step 77: f(x)= 0.225119
# differential_evolution step 78: f(x)= 0.225119
# differential_evolution step 79: f(x)= 0.224311
# differential_evolution step 80: f(x)= 0.224311
# differential_evolution step 81: f(x)= 0.224311
# differential_evolution step 82: f(x)= 0.224311
# differential_evolution step 83: f(x)= 0.224311
# differential_evolution step 84: f(x)= 0.224311
# differential_evolution step 85: f(x)= 0.224311
# Params [1.20204945e+00 4.67228433e+00 2.63494170e-02 1.09535428e+02
#  9.63902354e-01 1.03456997e-01 2.10639362e-01 1.19833143e-01] gave 0.22378992266030562
# 525
# differential_evolution step 1: f(x)= 2.42578
# differential_evolution step 2: f(x)= 1.43404
# differential_evolution step 3: f(x)= 1.01363
# differential_evolution step 4: f(x)= 0.619608
# differential_evolution step 5: f(x)= 0.619608
# differential_evolution step 6: f(x)= 0.619608
# differential_evolution step 7: f(x)= 0.619608
# differential_evolution step 8: f(x)= 0.619608
# differential_evolution step 9: f(x)= 0.575801
# differential_evolution step 10: f(x)= 0.575801
# differential_evolution step 11: f(x)= 0.495185
# differential_evolution step 12: f(x)= 0.495185
# differential_evolution step 13: f(x)= 0.45708
# differential_evolution step 14: f(x)= 0.421444
# differential_evolution step 15: f(x)= 0.421444
# differential_evolution step 16: f(x)= 0.34868
# differential_evolution step 17: f(x)= 0.34868
# differential_evolution step 18: f(x)= 0.34868
# differential_evolution step 19: f(x)= 0.34868
# differential_evolution step 20: f(x)= 0.348012
# differential_evolution step 21: f(x)= 0.281787
# differential_evolution step 22: f(x)= 0.281787
# differential_evolution step 23: f(x)= 0.254889
# differential_evolution step 24: f(x)= 0.254889
